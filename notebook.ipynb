# %% [markdown]
# ### Importing libraries to use

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ### Uploading dataset to work out

# %%
data = pd.read_csv('data.csv')  
data.head()
# Out:
#   ESTU_GENERO  PERIODO ESTU_PAIS_RESIDE ESTU_DEPTO_RESIDE ESTU_MCPIO_RESIDE  \
# 0           M     2020         COLOMBIA            BOGOTÁ       BOGOTÁ D.C.
# 1           M     2020        VENEZUELA            BOGOTÁ       BOGOTÁ D.C.
# 2           F     2020         COLOMBIA             CESAR          BOSCONIA
# 3           F     2020         COLOMBIA        LA GUAJIRA            MAICAO
# 4           F     2020         COLOMBIA         ATLANTICO      BARRANQUILLA
#
#              ESTU_VALORMATRICULAUNIVERSIDAD ESTU_PAGOMATRICULAPROPIO  \
# 0    Entre 1 millón y menos de 2.5 millones                       Si
# 1  Entre 4 millones y menos de 5.5 millones                       No
# 2         Entre 500 mil y menos de 1 millón                       No
# 3         Entre 500 mil y menos de 1 millón                       Si
# 4         Entre 500 mil y menos de 1 millón                       Si
#
#                     FAMI_EDUCACIONPADRE             FAMI_EDUCACIONMADRE  \
# ...

# %% [markdown]
# ### Scoping dataset to 2022-23 engineer popuplation from Bogota DC

# %%
degrees = ['INGENIERIA DE SISTEMAS', 'INGENIERIA DE SOFTWARE', 'INGENIERIA INFORMATICA', 'INGENIERIA DE SISTEMAS Y COMPUTACION', 
 'INGENIERIA DE SISTEMAS Y TELECOMUNICACIONES', 'INGENIERIA EN TELECOMUNICACIONES', 'INGENIERIA DE SISTEMAS E INFORMATICA', 
 'INGENIERIA DE SISTEMAS Y  COMPUTACIONINGENIERIA DE SISTEMAS DE INFORMACION', 'INGENIERIA EN  TELECOMUNICACIONES', 
 'INGENIERIA EN INFORMATICA', 'INGENIERIA DE SOFTWARE Y COMUNICACIONES', 'INGENIERIA DE SISTEMAS INFORMÁTICOS', 
 'INGENIERIA DE TELECOMUNICACIONES E INFORMATICA', 'INGENIERIA EN SOFTWARE', 'INGENIERIA DE SISTEMAS CIBERNETICOS', 
 'INGENIERIA DE SISTEMAS', 'INGENIERIA CIVIL', 'INGENIERIA METALURGICA', 'INGENIERIA DE MERCADOS', 'INGENIERIA AGRONOMICA', 
 'INGENIERIA INDUSTRIAL', 'INGENIERIA ELECTRONICA', 'INGENIERIA DE ALIMENTOS', 'INGENIERIA AMBIENTAL', 'INGENIERIA CATASTRAL Y GEODESIA', 
 'INGENIERIA MECANICA', 'INGENIERIA ELECTRICA', 'INGENIERIA DE SOFTWARE', 'INGENIERIA DE DISEÑO DE PRODUCTO', 'INGENIERIA FINANCIERA', 
 'INGENIERIA AGRICOLA', 'INGENIERIA AGROPECUARIA', 'INGENIERIA AERONAUTICA', 'INGENIERIA MECATRONICA', 'INGENIERIA QUIMICA', 
 'INGENIERIA AGROINDUSTRIAL', 'INGENIERIA TOPOGRAFICA', 'INGENIERIA AGROECOLOGICA', 'INGENIERIA DE PRODUCCION', 'INGENIERIA FORESTAL', 
 'INGENIERIA EN ENERGIAS', 'INGENIERIA EN CONTROL Y AUTOMATIZACIÓN', 'INGENIERIA MECATRÓNICA', 'INGENIERIA EN SEGURIDAD Y SALUD EN EL TRABAJO', 
 'INGENIERIA EN CONTROL ELECTRONICO E INSTRUMENTACION', 'INGENIERIA ELECTRICA POR CICLOS PROPEDEUTICOS.', 'INGENIERIA DE SISTEMAS CIBERNETICOS',
 'INGENIERIA EN AUTOMATIZACIÓN Y CONTROL']

data = data[data['ESTU_PRGM_ACADEMICO'].isin(degrees)]
data = data[data['PERIODO'].isin([2022,2023])]
data = data[data['ESTU_DEPTO_RESIDE'] == 'BOGOTÁ']
data = data.drop('PERIODO', axis=1)
data = data.drop('ESTU_MCPIO_RESIDE', axis=1)
data = data.drop('ESTU_DEPTO_RESIDE', axis=1)
data = data.drop('ESTU_PAIS_RESIDE', axis=1)
data = data[data['ESTU_PRGM_ACADEMICO'].isin(degrees)]
data = data.drop('ESTU_PRGM_ACADEMICO', axis=1)
data = data.drop('INST_NOMBRE_INSTITUCION', axis=1)
data = data.drop('Unnamed: 23', axis=1)
data = data.drop('CANT_DATOS', axis=1)
data
# Out:
#        ESTU_GENERO            ESTU_VALORMATRICULAUNIVERSIDAD  \
# 445674           F  Entre 4 millones y menos de 5.5 millones
# 445836           F  Entre 2.5 millones y menos de 4 millones
# 445839           F  Entre 5.5 millones y menos de 7 millones
# 445842           M                         No pagó matrícula
# 445843           M  Entre 5.5 millones y menos de 7 millones
# ...            ...                                       ...
# 662901           M    Entre 1 millón y menos de 2.5 millones
# 662902           M  Entre 4 millones y menos de 5.5 millones
# 662903           M  Entre 4 millones y menos de 5.5 millones
# 662953           F  Entre 4 millones y menos de 5.5 millones
# 663052           F                         No pagó matrícula
#
#        ESTU_PAGOMATRICULAPROPIO                 FAMI_EDUCACIONPADRE  \
# 445674                       Si  Secundaria (Bachillerato) completa
# 445836                       No                 Primaria incompleta
# ...

# %% [markdown]
# ### Cleaning from duplicates and Nan values to the dataset

# %%
data = data.drop_duplicates()
dats = data.dropna(how='any')
data
# Out:
#        ESTU_GENERO            ESTU_VALORMATRICULAUNIVERSIDAD  \
# 445674           F  Entre 4 millones y menos de 5.5 millones
# 445836           F  Entre 2.5 millones y menos de 4 millones
# 445839           F  Entre 5.5 millones y menos de 7 millones
# 445842           M                         No pagó matrícula
# 445843           M  Entre 5.5 millones y menos de 7 millones
# ...            ...                                       ...
# 662901           M    Entre 1 millón y menos de 2.5 millones
# 662902           M  Entre 4 millones y menos de 5.5 millones
# 662903           M  Entre 4 millones y menos de 5.5 millones
# 662953           F  Entre 4 millones y menos de 5.5 millones
# 663052           F                         No pagó matrícula
#
#        ESTU_PAGOMATRICULAPROPIO                 FAMI_EDUCACIONPADRE  \
# 445674                       Si  Secundaria (Bachillerato) completa
# 445836                       No                 Primaria incompleta
# ...
